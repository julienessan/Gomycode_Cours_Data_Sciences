# %% [markdown]
# <a href="https://colab.research.google.com/github/julienessan/Gomycode_Cours_Data_Sciences/blob/main/Checkpoint_Python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Checkpoint: Python basics **

# %% [markdown]
# **Objectif:**
# L'objectif du jeu est de deviner un nombre généré aléatoirement entre 1 et 100.

# %%
print("Bienvenue dans le jeu Devinez le nombre!")
# Out:
# Bienvenue dans le jeu Devinez le nombre!

# %%
print("Je pense à un nombre entre 1 et 100. Pouvez-vous le deviner ?")
# Out:
# Je pense à un nombre entre 1 et 100. Pouvez-vous le deviner ?

# %%
import random

# %%
nb_a_deviner = random.randint(1, 100)
# Out:
# 90

# %%
reponse = input("Entrez votre réponse")
reponse_int = int(reponse)
# Out:
# Entrez votre réponse90

# %%
if reponse_int > nb_a_deviner:
  print("Votre réponse est trop élevée. Réessayez.")
elif reponse_int < nb_a_deviner:
  print("Votre réponse est trop basse. Réessayez")
else :
  print("Félicitations ! Vous avez deviné le nombre correctement!")
# Out:
# Félicitations ! Vous avez deviné le nombre correctement!
